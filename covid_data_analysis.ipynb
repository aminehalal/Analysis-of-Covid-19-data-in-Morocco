# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('covid_data.csv')

# %%
data
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 260562      ZWE    Africa     Zimbabwe  2023-02-23     263921.0        NaN
# 260563      ZWE    Africa     Zimbabwe  2023-02-24     263921.0        NaN
# 260564      ZWE    Africa     Zimbabwe  2023-02-25     263921.0        NaN
# 260565      ZWE    Africa     Zimbabwe  2023-02-26     263921.0        NaN
# 260566      ZWE    Africa     Zimbabwe  2023-02-27     263921.0        NaN
#
# ...

# %%
data_morocco = data[data['location'] == 'Morocco']

# %%
data_morocco
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 156126      MAR    Africa  Morocco  2020-02-07          NaN        NaN
# 156127      MAR    Africa  Morocco  2020-02-08          NaN        NaN
# 156128      MAR    Africa  Morocco  2020-02-09          NaN        NaN
# 156129      MAR    Africa  Morocco  2020-02-10          NaN        NaN
# 156130      MAR    Africa  Morocco  2020-02-11          NaN        NaN
# ...         ...       ...      ...         ...          ...        ...
# 157238      MAR    Africa  Morocco  2023-02-23    1272418.0        7.0
# 157239      MAR    Africa  Morocco  2023-02-24    1272435.0       17.0
# 157240      MAR    Africa  Morocco  2023-02-25    1272442.0        7.0
# 157241      MAR    Africa  Morocco  2023-02-26    1272445.0        3.0
# 157242      MAR    Africa  Morocco  2023-02-27    1272446.0        1.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
data_morocco['death_rate'] = data_morocco['total_deaths'] / data_morocco['total_cases']
# Out:
# C:\Users\Halal\AppData\Local\Temp\ipykernel_4240\151537899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_morocco['death_rate'] = data_morocco['total_deaths'] / data_morocco['total_cases']

# %%
data_morocco.sample(10)
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 156698      MAR    Africa  Morocco  2021-09-01     866968.0     6020.0
# 156970      MAR    Africa  Morocco  2022-05-31    1168303.0      320.0
# 156688      MAR    Africa  Morocco  2021-08-22     810949.0     4661.0
# 156515      MAR    Africa  Morocco  2021-03-02     484159.0      393.0
# 156172      MAR    Africa  Morocco  2020-03-24        170.0       27.0
# 157059      MAR    Africa  Morocco  2022-08-28    1264316.0       30.0
# 156400      MAR    Africa  Morocco  2020-11-07     252185.0     5836.0
# 156938      MAR    Africa  Morocco  2022-04-29    1164907.0       42.0
# 157015      MAR    Africa  Morocco  2022-07-15    1248856.0     2021.0
# 157207      MAR    Africa  Morocco  2023-01-23    1272167.0        3.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 156698            5404.429       12749.0       100.0               95.714
# ...

# %%
data_morocco['injury_rate'] = data_morocco['total_cases'] / data_morocco['population']
# Out:
# C:\Users\Halal\AppData\Local\Temp\ipykernel_4240\633529886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_morocco['injury_rate'] = data_morocco['total_cases'] / data_morocco['population']

# %%
data_morocco.head(20)
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 156126      MAR    Africa  Morocco  2020-02-07          NaN        NaN
# 156127      MAR    Africa  Morocco  2020-02-08          NaN        NaN
# 156128      MAR    Africa  Morocco  2020-02-09          NaN        NaN
# 156129      MAR    Africa  Morocco  2020-02-10          NaN        NaN
# 156130      MAR    Africa  Morocco  2020-02-11          NaN        NaN
# 156131      MAR    Africa  Morocco  2020-02-12          NaN        NaN
# 156132      MAR    Africa  Morocco  2020-02-13          NaN        NaN
# 156133      MAR    Africa  Morocco  2020-02-14          NaN        NaN
# 156134      MAR    Africa  Morocco  2020-02-15          NaN        NaN
# 156135      MAR    Africa  Morocco  2020-02-16          NaN        NaN
# 156136      MAR    Africa  Morocco  2020-02-17          NaN        NaN
# 156137      MAR    Africa  Morocco  2020-02-18          NaN        NaN
# ...

# %%
data_morocco.sample(10)
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 156881      MAR    Africa  Morocco  2022-03-03    1161392.0      102.0
# 156186      MAR    Africa  Morocco  2020-04-07       1184.0       64.0
# 156930      MAR    Africa  Morocco  2022-04-21    1164567.0       60.0
# 156864      MAR    Africa  Morocco  2022-02-14    1155534.0      369.0
# 156624      MAR    Africa  Morocco  2021-06-19     526363.0      439.0
# 156652      MAR    Africa  Morocco  2021-07-17     555488.0     2853.0
# 157239      MAR    Africa  Morocco  2023-02-24    1272435.0       17.0
# 157221      MAR    Africa  Morocco  2023-02-06    1272281.0        1.0
# 156416      MAR    Africa  Morocco  2020-11-23     327528.0     2587.0
# 156753      MAR    Africa  Morocco  2021-10-26     944803.0      425.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 156881             155.571       16006.0         4.0                7.714
# ...

# %%
data_morocco.to_csv('data_morocco.csv')
